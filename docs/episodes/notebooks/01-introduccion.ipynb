# %% [markdown]
# # Episodio 1 - Introduccion y entorno de trabajo
#
# Este notebook verifica el entorno y carga una estructura PDB simple.

# %%
from openmm import app
import openmm as mm
print('OpenMM', mm.__version__)

# %%
pdb = app.PDBFile('../../data/alanine-dipeptide.pdb')
print('Atoms:', pdb.topology.getNumAtoms())
