# %% [markdown]
# # Episode 6 - MSMs with PyEMMA
#
# ## Simple track: alanine dipeptide
#
# In this notebook you build MSMs with PyEMMA step by step.
# You will use alanine dipeptide trajectories to train and validate the model.

# %% [markdown]
# ## Table of contents
#
# - [Simple track: alanine dipeptide](#simple-track-alanine-dipeptide)
# - [Simple track: alanine dipeptide](#simple-track-alanine-dipeptide)
# - [Step 1](#step-1)

# %% [markdown]
# Build MSMs for alanine step-by-step: featurize, apply TICA, cluster, and compute implied timescales.

# %% [markdown]
# ## Step 1

# %%
#!/usr/bin/env python3
import argparse
import os
from pathlib import Path
import numpy as np
import pyemma
import matplotlib.pyplot as plt
import time
import pyemma.plots
COURSE_DIR = Path(os.environ.get("COURSE_DIR", str(Path.home() / "Concepcion26"))).expanduser()


def load_features(topology: str):
    feat = pyemma.coordinates.featurizer(topology)
    feat.add_backbone_torsions(periodic=False)
    return feat


def run_pipeline(traj_files, topology, lag, k):
    feat = load_features(topology)
    data = pyemma.coordinates.load(traj_files, features=feat)

    tica = pyemma.coordinates.tica(data, lag=lag)
    tica_output = tica.get_output()

    cluster = pyemma.coordinates.cluster_kmeans(tica_output, k=k, max_iter=50)
    msm = pyemma.msm.estimate_markov_model(cluster.dtrajs, lag=lag)

    return data, tica, cluster, msm


def main() -> None:
    parser = argparse.ArgumentParser(description="PyEMMA tutorials on alanine dipeptide")
    parser.add_argument("-t", "--traj", nargs="+", default=None, help="Trajectory files")
    parser.add_argument("-p", "--top", default=None, help="Topology PDB")
    parser.add_argument("--lag", type=int, default=10, help="Lag time")
    parser.add_argument("-k", type=int, default=50, help="Number of clusters")
    args, _ = parser.parse_known_args()

    data_dir = COURSE_DIR / "data"
    dcd_path = data_dir / "alanine-dipeptide.dcd"
    traj_files = args.traj or [str(dcd_path)]
    topology = args.top or str(data_dir / "alanine-dipeptide.pdb")
    if args.traj is None and not dcd_path.exists():
        print("Missing DCD:", dcd_path)
        print("Run the alanine dipeptide simulation notebook first to generate it.")
        return

    out_dir = COURSE_DIR / "results" / "06-pyemma" / "simple"
    out_dir.mkdir(parents=True, exist_ok=True)
    run_tag = time.strftime("%Y%m%d-%H%M%S")
    data, tica, cluster, msm = run_pipeline(traj_files, topology, args.lag, args.k)

    print("Tutorial 01 - Data IO & featurization: OK")
    print("Feature dimension:", tica.dimension())

    print("Tutorial 02 - TICA & clustering: OK")
    print("TICA lag:", tica.lag)

    print("Tutorial 03 - MSM estimation & validation")
    its = pyemma.msm.its(cluster.dtrajs, lags=[1, 2, 5, 10])
    print("ITS computed for", len(its.lags), "lags")
    plt.figure()
    pyemma.plots.plot_implied_timescales(its)
    plt.savefig(out_dir / f"its_{run_tag}.png", dpi=150)

    print("Tutorial 04 - MSM analysis")
    timescales = msm.timescales()[:5]
    print("Timescales:", timescales)
    (out_dir / f"timescales_{run_tag}.txt").write_text("\n".join(str(t) for t in timescales))

    print("Tutorial 05 - PCCA & TPT")
    try:
        msm.pcca(2)
        tpt = pyemma.msm.tpt(msm, msm.active_set[0], msm.active_set[-1])
        print("TPT flux:", tpt.total_flux)
    except Exception as exc:
        print("PCCA/TPT skipped:", exc)

    print("Tutorial 06 - Expectations & observables")
    try:
        obs = data[0][:, 0]
        print("Observable mean:", float(np.mean(obs)))
    except Exception as exc:
        print("Observables skipped:", exc)

    print("Tutorial 07 - HMM")
    try:
        hmm = pyemma.msm.bayesian_hidden_markov_model(cluster.dtrajs, nstates=2, lag=args.lag)
        print("HMM timescales:", hmm.timescales()[:3])
    except Exception as exc:
        print("HMM skipped:", exc)

    print("Tutorial 08 - Common problems")
    print("Active fraction:", msm.active_state_fraction)
    print("Connected count fraction:", msm.active_count_fraction)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 93
#      89     print("Connected count fraction:", msm.active_count_fraction)
#      92 if __name__ == "__main__":
# ---> 93     main()
#
# Cell In[1], line 45, in main()
#      43 out_dir = COURSE_DIR / "results" / "06-pyemma" / "simple"
#      44 out_dir.mkdir(parents=True, exist_ok=True)
# ---> 45 data, tica, cluster, msm = run_pipeline(traj_files, topology, args.lag, args.k)
#      47 print("Tutorial 01 - Data IO & featurization: OK")
#      48 print("Feature dimension:", tica.dimension())
#
# Cell In[1], line 20, in run_pipeline(traj_files, topology, lag, k)
#      18 def run_pipeline(traj_files, topology, lag, k):
#      19     feat = load_features(topology)
# ---> 20     data = pyemma.coordinates.load(traj_files, features=feat)
#      22     tica = pyemma.coordinates.tica(data, lag=lag)
#      23     tica_output = tica.get_output()
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/pyemma/coordinates/api.py:246, in load(trajfiles, features, top, stride, chunksize, **kw)
#     241 cs = _check_old_chunksize_arg(chunksize, get_default_args(load)['chunksize'], **kw)
#     242 if isinstance(trajfiles, _string_types) or (
#     243     isinstance(trajfiles, (list, tuple))
#     244         and (any(isinstance(item, (list, tuple, str)) for item in trajfiles)
#     245              or len(trajfiles) == 0)):
# --> 246     reader = create_file_reader(trajfiles, top, features, chunksize=cs, **kw)
#     247     trajs = reader.get_output(stride=stride)
#     248     if len(trajs) == 1:
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/pyemma/coordinates/data/util/reader_utils.py:117, in create_file_reader(input_files, topology, featurizer, chunksize, **kw)
#     113     if suffix in ('.pdb', '.pdb.gz'):
#     114         raise ValueError('PyEMMA can not read PDB-fake-trajectories. '
#     115                          'Please consider using a sane trajectory format (e.g. xtc, dcd).')
# --> 117     reader = FeatureReader(input_list, featurizer=featurizer, topologyfile=topology,
#     118                            chunksize=chunksize)
#     119 elif suffix in ('.npy', '.npz'):
#     120     reader = NumPyFileReader(input_list, chunksize=chunksize)
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/pyemma/coordinates/data/feature_reader.py:126, in FeatureReader.__init__(self, trajectories, topologyfile, chunksize, featurizer)
#     123     self.topfile = featurizer.topologyfile
#     125 # Check that the topology and the files in the filelist can actually work together
# --> 126 self._assert_toptraj_consistency()
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/pyemma/coordinates/data/feature_reader.py:211, in FeatureReader._assert_toptraj_consistency(self)
#     209 r""" Check if the topology and the filenames of the reader have the same n_atoms"""
#     210 top = self.featurizer.topology
# --> 211 traj = mdtraj.load_frame(self.filenames[0], index=0, top=top)
#     212 desired_n_atoms = top.n_atoms
#     213 assert traj.xyz.shape[1] == desired_n_atoms, "Mismatch in the number of atoms between the topology" \
#     214                                              " and the first trajectory file, %u vs %u" % \
#     215                                              (desired_n_atoms, traj.xyz.shape[1])
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/mdtraj/core/trajectory.py:312, in load_frame(filename, index, top, atom_indices, **kwargs)
#     309 else:
#     310     _assert_files_or_dirs_exist(filename)
# --> 312 return loader(filename, frame=index, **kwargs)
#
# File mdtraj/formats/dcd/dcd.pyx:165, in mdtraj.formats.dcd.load_dcd()
#
# File mdtraj/formats/dcd/dcd.pyx:171, in mdtraj.formats.dcd.load_dcd()
#
# File mdtraj/formats/dcd/dcd.pyx:421, in mdtraj.formats.dcd.DCDTrajectoryFile.read_as_traj()
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/mdtraj/core/trajectory.py:1317, in Trajectory.__init__(self, xyz, topology, time, unitcell_lengths, unitcell_angles)
#    1306 def __init__(
#    1307     self,
#    1308     xyz,
#    (...)
#    1314     # install the topology into the object first, so that when setting
#    1315     # the xyz, we can check that it lines up (e.g. n_atoms), with the topology
#    1316     self.topology = topology
# -> 1317     self.xyz = xyz
#    1319     # _rmsd_traces are the inner product of each centered conformation,
#    1320     # which are required for computing RMSD. Normally these values are
#    1321     # calculated on the fly in the cython code (rmsd/_rmsd.pyx), but
#    (...)
#    1325     # self._rmsd_traces. This array is populated computed by
#    1326     # center_conformations, and no other methods should really touch it.
#    1327     self._rmsd_traces = None
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/mdtraj/core/trajectory.py:973, in Trajectory.xyz(self, value)
#     970 else:
#     971     shape = (None, None, 3)
# --> 973 value = ensure_type(
#     974     value,
#     975     np.float32,
#     976     3,
#     977     "xyz",
#     978     shape=shape,
#     979     warn_on_cast=False,
#     980     add_newaxis_on_deficient_ndim=True,
#     981 )
#     982 self._xyz = value
#     983 self._rmsd_traces = None
#
# File ~/miniconda3/envs/pyemma/lib/python3.9/site-packages/mdtraj/utils/validation.py:157, in ensure_type(val, dtype, ndim, name, length, can_be_none, shape, warn_on_cast, add_newaxis_on_deficient_ndim)
#     154             continue
#     155         if a != b:
#     156             # check for equality
# --> 157             raise error
#     159 return val
#
# ValueError: xyz must be shape (Any, 10, 3). You supplied  (1, 22, 3)
